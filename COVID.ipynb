# %%
import json
import requests
import pandas as pd

# %% [markdown]
# # States

# %%
stateResponse = requests.get("https://covidtracking.com/api/v1/states/daily.json")
print(stateResponse)

states = pd.DataFrame(json.loads(stateResponse.text))
states.head()
# Out:
# <Response [200]>
#        date state  positive  negative  pending  hospitalizedCurrently  \
# 0  20200411    AK     257.0    7475.0      NaN                    NaN
# 1  20200411    AL    3191.0   18058.0      NaN                    NaN
# 2  20200411    AR    1226.0   17352.0      NaN                   86.0
# 3  20200411    AS       0.0       3.0      2.0                    NaN
# 4  20200411    AZ    3393.0   37137.0      NaN                    NaN
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                    31.0             NaN              NaN
# 1                   402.0             NaN              NaN
# 2                   130.0             NaN             43.0
# 3                     NaN             NaN              NaN
# 4                     NaN             NaN              NaN
#
#    onVentilatorCurrently  ...  hospitalized    total totalTestResults  \
# 0                    NaN  ...          31.0   7732.0           7732.0
# 1                    NaN  ...         402.0  21249.0          21249.0
# 2                   33.0  ...         130.0  18578.0          18578.0
# 3                    NaN  ...           NaN      5.0              3.0
# 4                    NaN  ...           NaN  40530.0          40530.0
#
#     posNeg  fips  deathIncrease  hospitalizedIncrease  negativeIncrease  \
# 0   7732.0    02            1.0                   3.0             289.0
# 1  21249.0    01           11.0                  34.0               0.0
# 2  18578.0    05            1.0                   0.0            1403.0
# 3      3.0    60            0.0                   0.0               0.0
# 4  40530.0    04           11.0                   0.0            2515.0
#
#    positiveIncrease totalTestResultsIncrease
# 0              11.0                    300.0
# 1             223.0                    223.0
# 2              55.0                   1458.0
# 3               0.0                      0.0
# 4             281.0                   2796.0
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Colorado

# %%
co = df[df['state'] == 'CO']
co.loc[:,'date'] = pd.to_datetime(co.loc[:,'date'], format='%Y%m%d').dt.date
co.head()
# Out:
#            date state  positive  negative  pending  hospitalizedCurrently  \
# 6    2020-04-11    CO    6510.0   26143.0      NaN                    NaN
# 62   2020-04-10    CO    6510.0   26143.0      NaN                    NaN
# 118  2020-04-09    CO    5655.0   23544.0      NaN                    NaN
# 174  2020-04-08    CO    5429.0   22665.0      NaN                    NaN
# 230  2020-04-07    CO    5172.0   21703.0      NaN                    NaN
#
#      hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 6                    1312.0             NaN              NaN
# 62                   1312.0             NaN              NaN
# 118                  1162.0             NaN              NaN
# 174                  1079.0             NaN              NaN
# 230                   994.0             NaN              NaN
#
#      onVentilatorCurrently  ...  hospitalized    total totalTestResults  \
# 6                      NaN  ...        1312.0  32653.0          32653.0
# 62                     NaN  ...        1312.0  32653.0          32653.0
# 118                    NaN  ...        1162.0  29199.0          29199.0
# 174                    NaN  ...        1079.0  28094.0          28094.0
# 230                    NaN  ...         994.0  26875.0          26875.0
#
#       posNeg  fips  deathIncrease  hospitalizedIncrease  negativeIncrease  \
# 6    32653.0    08            0.0                   0.0               0.0
# 62   32653.0    08           57.0                 150.0            2599.0
# 118  29199.0    08           14.0                  83.0             879.0
# 174  28094.0    08           29.0                  85.0             962.0
# 230  26875.0    08           10.0                  70.0             880.0
#
#      positiveIncrease totalTestResultsIncrease
# 6                 0.0                      0.0
# 62              855.0                   3454.0
# 118             226.0                   1105.0
# 174             257.0                   1219.0
# 230             222.0                   1102.0
#
# [5 rows x 25 columns]

# %%
co.sort_values(by='date').plot.bar(x='date', y='positiveIncrease')

# %% [markdown]
# ## South Carolina

# %%
sc = df[df['state'] == 'SC']
sc.loc[:,'date'] = pd.to_datetime(sc.loc[:,'date'], format='%Y%m%d').dt.date
sc.head()
# Out:
#            date state  positive  negative  pending  hospitalizedCurrently  \
# 44   2020-04-11    SC    3207.0   26886.0      NaN                    NaN
# 100  2020-04-10    SC    3065.0   25118.0      NaN                    NaN
# 156  2020-04-09    SC    2792.0   24575.0      NaN                    NaN
# 212  2020-04-08    SC    2552.0   22082.0      NaN                    NaN
# 268  2020-04-07    SC    2417.0   21263.0      NaN                    NaN
#
#      hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 44                    496.0             NaN              NaN
# 100                   496.0             NaN              NaN
# 156                   241.0             NaN              NaN
# 212                   241.0             NaN              NaN
# 268                   241.0             NaN              NaN
#
#      onVentilatorCurrently  ...  hospitalized    total totalTestResults  \
# 44                     NaN  ...         496.0  30093.0          30093.0
# 100                    NaN  ...         496.0  28183.0          28183.0
# 156                    NaN  ...         241.0  27367.0          27367.0
# 212                    NaN  ...         241.0  24634.0          24634.0
# 268                    NaN  ...         241.0  23680.0          23680.0
#
#       posNeg  fips  deathIncrease  hospitalizedIncrease  negativeIncrease  \
# 44   30093.0    45            8.0                   0.0            1768.0
# 100  28183.0    45            5.0                 255.0             543.0
# 156  27367.0    45            4.0                   0.0            2493.0
# 212  24634.0    45           12.0                   0.0             819.0
# 268  23680.0    45            7.0                   0.0            4336.0
#
#      positiveIncrease totalTestResultsIncrease
# 44              142.0                   1910.0
# 100             273.0                    816.0
# 156             240.0                   2733.0
# 212             135.0                    954.0
# 268             368.0                   4704.0
#
# [5 rows x 25 columns]

# %%
sc.sort_values(by='date').plot.bar(x='date', y='positiveIncrease')
